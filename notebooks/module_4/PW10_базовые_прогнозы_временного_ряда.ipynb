# %% [markdown]
# # Практическая работа 10. Базовые прогнозы временного ряда
# - Создать честный baseline
# - Использовать хронологический test

# %% [markdown]
# ## Цель и результат
#
# Создать честный baseline; Использовать хронологический test.
#
# ## Самостоятельное задание
#
# Измените один параметр метода, сравните результат и объясните его значение для аквакультуры.
#
# ## Контрольные вопросы
#
# 1. Какую ошибку предотвращает использованный протокол?
# 2. Как интерпретировать результат для специалиста рыбного хозяйства?
#
# ## Оценивание
#
# Используйте общую аналитическую рубрику из `assessments/rubric.md`.

# %%
import pandas as pd
from sklearn.metrics import mean_absolute_error
df=pd.read_csv("../../data/hydrochem_timeseries.csv",parse_dates=["timestamp"]).set_index("timestamp")
s=df.dissolved_oxygen_mgL; pred=s.shift(1); cut=int(len(s)*.8)
print("Test MAE",mean_absolute_error(s.iloc[cut:],pred.iloc[cut:]))
