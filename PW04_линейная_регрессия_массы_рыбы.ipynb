# %% [markdown]
# # Практическая работа 4. Линейная регрессия массы рыбы
# - Построить модель
# - Интерпретировать MAE и R²

# %% [markdown]
# ## Цель и результат
#
# Построить модель; Интерпретировать MAE и R².
#
# ## Самостоятельное задание
#
# Измените один параметр метода, сравните результат и объясните его значение для аквакультуры.
#
# ## Контрольные вопросы
#
# 1. Какую ошибку предотвращает использованный протокол?
# 2. Как интерпретировать результат для специалиста рыбного хозяйства?
#
# ## Оценивание
#
# Используйте общую аналитическую рубрику из `assessments/rubric.md`.

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error,r2_score
df=pd.read_csv("../../fish_growth_dataset.csv"); df=pd.get_dummies(df,columns=["species"],drop_first=True)
X=df.drop(columns="weight_g");y=df.weight_g
Xtr,Xte,ytr,yte=train_test_split(X,y,test_size=.2,random_state=42)
m=LinearRegression().fit(Xtr,ytr);p=m.predict(Xte)
print("MAE",mean_absolute_error(yte,p),"R2",r2_score(yte,p))
